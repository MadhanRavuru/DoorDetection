# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Siemens Work/DoorDetection'    #project folder directory
# Out:
# Mounted at /content/gdrive

# %%
# %cd 'gdrive/My Drive/Siemens Work/DoorDetection'
# Out:
# /content/gdrive/My Drive/Siemens Work/DoorDetection

# %%
# !ls
# Out:
# bbox.py        data	    PyTorch_Object_Detection.ipynb  TrainValSplit.py
# checkpoints    images	    README.md			    utils
# config	       models.py    Training.ipynb
# createlist.py  __pycache__  train.py

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# [W IndexingUtils.h:20] Warning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)
# [W IndexingUtils.h:20] Warning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)
# [W IndexingUtils.h:20] Warning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)
# [W IndexingUtils.h:20] Warning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)
# [Epoch 19/21, Batch 82/155] [Losses: x 0.027911, y 0.024642, w 0.025766, h 0.040214, conf 0.176614, cls 0.000000, total 0.295147, recall: 1.00000, precision: 0.04488]
# [W IndexingUtils.h:20] Warning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)
# ...
